# %% [markdown]
# # Know the Data

# %%
import pandas as pd

# %%
data = pd.read_csv("Banknote_Authentication.csv")
data.head(5)
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data.tail(5)
# Out:
#       variance  skewness  curtosis  entropy  class
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1

# %%
data.shape
# Out:
# (1372, 5)

# %%
data.isnull().sum()
# Out:
# variance    0
# skewness    0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %%
data.describe()
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
X = data.iloc[:,0:4]
y = data.iloc[:,-1]

# %%
X.head()
# Out:
#    variance  skewness  curtosis  entropy
# 0   3.62160    8.6661   -2.8073 -0.44699
# 1   4.54590    8.1674   -2.4586 -1.46210
# 2   3.86600   -2.6383    1.9242  0.10645
# 3   3.45660    9.5228   -4.0112 -3.59440
# 4   0.32924   -4.4552    4.5718 -0.98880

# %% [markdown]
# # Balancing The Data

# %%
y.value_counts()
# Out:
# 0    762
# 1    610
# Name: class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
X, y = sm.fit_resample(X,y)
pd.Series(y).value_counts()
# Out:
# 1    762
# 0    762
# Name: class, dtype: int64

# %% [markdown]
# # Train-Test

# %%
X.shape, y.shape
# Out:
# ((1524, 4), (1524,))

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting into training and testing sets
X_train,X_test,y_train,y_test = train_test_split(X ,y,test_size=0.2,random_state=8)

# %%
X_train.shape, y_train.shape
# Out:
# ((1219, 4), (1219,))

# %% [markdown]
# # Scaling The Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.68297889, 0.87367234, 0.08781097, 0.64503487],
#        [0.33333333, 0.51046172, 0.25793439, 0.81528774],
#        [0.53157519, 0.35157509, 0.42466237, 0.6873619 ],
#        ...,
#        [0.75192725, 0.64295767, 0.26690374, 0.80012003],
#        [0.30309586, 0.26951738, 0.67938915, 0.73897906],
#        [0.91751581, 0.81378923, 0.11205979, 0.69312311]])

# %%
X_test.shape, y_test.shape
# Out:
# ((305, 4), (305,))

# %% [markdown]
# # Model with Custom Activation Function

# %%
col = X_train.shape[1] 
k = 2 * np.random.random((1,col)) - 1

k_array = []

# %%
for _ in range(10):
    xx,X_part ,yy, y_part = train_test_split(X_train ,y_train,test_size=0.7,random_state=8)
    
    try:
        for iter in range(5000):
            layer0 = X_part           
            layer1 = np.dot(k, layer0.T)                                    

            #l1_error = l1_error.res
            y_part = y_part.to_numpy()
            #layer1 = layer1.reshape(1,-1)
            
            l1_error = layer1 - y_part                   
            l1_delta = np.dot(l1_error * k)    
            net_change1 = np.dot(layer1.T, l1_delta)

            l1_error = l2_delta.dot(weights1.T)           
            l1_delta = l1_error  * derivativeSig(layer1)  
            net_change1 = np.dot(layer0.T, l1_delta)

            k_array.append(k)
            k = k - learning_rate*net_change1
        print(k)
    except Exception as e:
            print(layer1.shape)
            print(layer1.shape , k.shape)
            print(e)
# Out:
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)
# (1, 854)
# (1, 854) (1, 4)
# operands could not be broadcast together with shapes (1,854) (1,4)

# %%
a = np.array([2,5,6,7,8,9])
b = np.array([2,5,1,73,81,9])

# %%
a - b
# Out:
# array([  0,   0,   5, -66, -73,   0])

# %%
a.shape
# Out:
# (6,)

# %%
def build_model(acti_func):
    model=Sequential()
    model.add(Dense(10,activation=,input_dim=4))
    model.add(Dense(1,activation = acti_func))
    model.add(Dense(1))

# %% [markdown]
# # Model Building Through Deep Learning

# %% [markdown]
# ## Model

# %%
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
model=Sequential()
model.add(Dense(10,activation='relu',input_dim=4))
model.add(Dense(1,activation='sigmoid'))
model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_30 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 11
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 2
# ...
# Total params: 63
# Trainable params: 63
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
    #tf.keras.callbacks.TensorBoard(log_dir = 'logs')
]

# %%
results = model.fit(X_train, y_train, validation_split=0.2, batch_size=25, epochs=60, callbacks=callbacks)
# Out:
# Epoch 1/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9179 - val_loss: 0.3536 - val_accuracy: 0.8852
# Epoch 2/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.9262 - val_loss: 0.3419 - val_accuracy: 0.8770
# Epoch 3/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2395 - accuracy: 0.9272 - val_loss: 0.3271 - val_accuracy: 0.8852
# Epoch 4/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9303 - val_loss: 0.3139 - val_accuracy: 0.8934
# Epoch 5/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2140 - accuracy: 0.9354 - val_loss: 0.3059 - val_accuracy: 0.9016
# Epoch 6/60
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9364 - val_loss: 0.2898 - val_accuracy: 0.9016
# Epoch 7/60
# ...

# %% [markdown]
# ## Result Evaluation

# %%
model.evaluate(X_test,y_test,verbose=2)
# Out:
# 10/10 - 0s - loss: 0.0556 - accuracy: 0.9902
# [0.05561000481247902, 0.9901639223098755]

# %%
predict = model.predict(X_test)
predictions = predict > 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[153,   1],
#        [  2, 149]], dtype=int64)

# %%
model.save('banknote_model.h5')  # creates a HDF5 file 'my_model.h5'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()
